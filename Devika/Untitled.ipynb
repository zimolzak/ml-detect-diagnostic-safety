# %%
import pandas as pd

# %%
cohort = pd.read_csv('data/cohort_data.csv',header=None)
cohort.columns = ['PatientSSN','EDStartDateTime','EDEndDateTime','EDVisitReason','AdmitDateTime','DischargeDateTime',
                  'OutpatientVisitSID','InpatientSID','PatientSID','sta3n','StudyID']
cohort

# %%
demographics = pd.read_csv('data/demographics_data.csv',header=None)
demographics.columns = ['PatientSSN','IndexDateTime','DOB','Gender','Ethnicity','Race']
demographics

# %%
labdata = pd.read_csv('data/labtests.csv',header=None)
labdata.columns = ['PatientSSN','LabChemSpecimenDateTime','LabChemResultValue','LabChemResultNumericValue','Abnormal',
                  'LabChemTestName','RequestLocation','LOINC','LabChemSID','sta3n','LabChemTestSID','PatientSID']
labdata

# %%
radiology = pd.read_csv('data/radiology.csv',header=None)
radiology.columns = ['PatientSSN','ExamDateTime','CPTCode','CPTName','RadiologyDiagnosticCode','RadiologyExamSID',
                    'sta3n','PatientSID','RadiologyProcedureSID']

# %%
meds = pd.read_csv('data/medications.csv',header=None)
meds.columns=['PatientSSN','IssueDateTime','DrugClass','LocalDrugNameWithDose','NationalDrugNameWithDose','NDC',
             'sta3n','PatientSID','RxOutpatientSID','LocalDrugSID']
meds

# %%
meds_bcma = pd.read_csv('data/meds_bcma.csv',header=None)
meds_bcma.columns=['ActionDateTime','PatientSSN','sta3n','PatientSID','DrugClass','LocalDrugNameWithDose','NationalDrugNameWithDose','NDC',
             'BCMADispensedDrugSID','LocalDrugSID']
meds_bcma

# %%
meds_nonVA = pd.read_csv('data/meds_nonva.csv',header=None)
meds_nonVA.columns = ['StartDateTime','PatientSSN','sta3n','PatientSID','DrugClass','LocalDrugNameWithDose','NationalDrugNameWithDose',
                      'NDC','NonVAMedSID','LocalDrugSID']
meds_nonVA

# %%
allmeds = pd.read_csv('data/allmeds.csv',header=None)
allmeds.columns = ['PatientSSN','IssueDateTime','DrugClass','LocalDrugNameWithDose','NationalDrugNameWithDose','NDC',
                  'sta3n','PatientSID','UniqueSID','src','LocalDrugSID']
allmeds

# %%
consults = pd.read_csv('data/consults.csv',header=None)
consults.columns = ['PatientSSN','sta3n','PatientSID','RequestDateTime','CPRSOrderResultsDateTime','RequestType','ConStopCode',
                   'ConStopCodeName','ToRequestServiceName','ConsultSID','ToRequestServiceSID']
consults

# %%
icds = pd.read_csv('data/icds.csv',header=None)
icds.columns = ['PatientSSN','DiagDateTime','ICD','ICDDiagnosis','IsPrincipalDiag']
icds

# %%
vitals = pd.read_csv('data/vitals.csv',header=None)
vitals.columns = ['PatientSSN','VitalSignTakenDateTime','VitalType','VitalResult','VitalResultNumeric','Systolic','Diastolic',
               'SupplementalO2','LocationSID','VitalSignSID','sta3n','PatientSID']
vitals

# %%
healthfactors = pd.read_csv('data/healthfactors.csv',header=None)
healthfactors.columns = ['PatientSSN','HealthFactorType','EventDateTime','VisitDateTime','HealthFactorDateTime',
                        'LevelSeverity','VisitSID','VerifiedStatus','Comments','sta3n','PatientSID','HealthFactorSID']
healthfactors

# %%
notes = pd.read_csv('data/notes.csv',header=None)
notes.columns = ['PatientSSN','EntryDateTime','TIUDocumentSID','TIUStandardTitle','ReportText','sta3n','PatientSID']
notes

# %% [markdown]
# # Exploratory data analysis
# - why does a patient come into the ER?
# - how long do they spend in the ER visit?

# %%
tmp = cohort.EDVisitReason.str.lower().value_counts()
tmp[tmp >= 3].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
cohort.EDStartDateTime = pd.to_datetime(cohort.EDStartDateTime)
cohort.EDEndDateTime = pd.to_datetime(cohort.EDEndDateTime)
tmp = (cohort.EDEndDateTime - cohort.EDStartDateTime)
tmp.
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...
