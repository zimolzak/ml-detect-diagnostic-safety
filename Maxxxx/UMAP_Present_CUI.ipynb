# %% [markdown]
# # UMAP Experiment with Present only trained CUIs

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from tqdm import tqdm
import json
import umap
import matplotlib
import matplotlib.pyplot as plt
import umapplot

# %%
cuiids, cuiarray, vocab, cui_data, doc_vectors, embedding = \
    umapplot.do_everything("present_cui_vectors_6_MAR_2022.json", "sids_to_present_cuis.json", umap.UMAP())
# Out:
# (101991, 100)
#   2%|█▉                                                                          | 741/29865 [00:00<00:17, 1645.91it/s]
# doc has no cuis: 1000866475304
#   8%|██████▏                                                                    | 2482/29865 [00:01<00:13, 1983.80it/s]
# doc has no cuis: 1000902924496
#  10%|███████▋                                                                   | 3068/29865 [00:01<00:15, 1724.90it/s]
# doc has no cuis: 1000920278073
#  31%|███████████████████████                                                    | 9186/29865 [00:05<00:11, 1798.59it/s]
# doc has no cuis: 1001037237996
#  33%|████████████████████████▉                                                  | 9910/29865 [00:05<00:13, 1524.85it/s]
# doc has no cuis: 1201142915600
# 100%|██████████████████████████████████████████████████████████████████████████| 29865/29865 [00:19<00:00, 1566.77it/s]
# ...

# %%
umapplot.plot_highlights(cui_data, embedding)

# %%
cuiids2, cuiarray2, vocab2, cuidata2, doc_vectors2, embedding2 = \
    umapplot.do_everything("present_cui_vectors_6_MAR_2022.json", "sids_to_clamp_cuis.json", umap.UMAP(), mapper=umapplot.neg_absent_docvec_builder)

# %%
umapplot.plot_highlights(cuidata2, embedding2)
